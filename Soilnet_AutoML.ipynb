# %%
from google.colab import drive

drive.mount("/content/gdrive", force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !pip install h2o
# Out:
# Collecting h2o
#   Downloading https://files.pythonhosted.org/packages/bb/55/494a42e7509d0874aa444ae4cad0bc7439c936b40e563550fbfabb540275/h2o-3.30.1.3.tar.gz (129.4MB)
#      |████████████████████████████████| 129.4MB 87kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from h2o) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from h2o) (0.8.7)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from h2o) (0.16.0)
# Collecting colorama>=0.3.8
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->h2o) (3.0.4)
# Building wheels for collected packages: h2o
#   Building wheel for h2o (setup.py) ... done
#   Created wheel for h2o: filename=h2o-3.30.1.3-py2.py3-none-any.whl size=129446676 sha256=5bd6394fe2976cfd918d38c125cda206d7c69f4a6bb4aa2c5b95c5ca225c07a0
#   Stored in directory: /root/.cache/pip/wheels/3d/e6/07/53ce9be9cb61b33a79cb3ed1fc39f2dae84f6ee6fe1e373e5e
# Successfully built h2o
# Installing collected packages: colorama, h2o
# Successfully installed colorama-0.4.4 h2o-3.30.1.3

# %%
import h2o
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from h2o.automl import H2OAutoML
from sklearn.metrics import mean_squared_error, r2_score

# %%
global_seed = 42
np.random.seed = global_seed

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.9" 2020-10-20; OpenJDK Runtime Environment (build 11.0.9+11-Ubuntu-0ubuntu1.18.04.1); OpenJDK 64-Bit Server VM (build 11.0.9+11-Ubuntu-0ubuntu1.18.04.1, mixed mode, sharing)
#   Starting server from /usr/local/lib/python3.6/dist-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpouqrtrg6
#   JVM stdout: /tmp/tmpouqrtrg6/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpouqrtrg6/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         03 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# H2O_cluster_version_age:    1 month and 5 days
# H2O_cluster_name:           H2O_from_python_unknownUser_dwcby9
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    3.180 Gb
# H2O_cluster_total_cores:    2
# H2O_cluster_allowed_cores:  2
# H2O_cluster_status:         accepting new members, healthy
# H2O_connection_url:         http://127.0.0.1:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.6.9 final
# --------------------------  ------------------------------------------------------------------

# %%
def featureSelect(depth, mode=0, check=False):
    """
    enter only 2/10/50 for depth
    """
    if depth == 2 or depth == 10:
        alt = "L1"
    elif depth == 50:
        alt = "L3"

    ntr = ["NTR"]
    ndvi = ["NDVI"]
    psd = [f"Clay_{alt}", f"Sand_{alt}", f"Silt_{alt}"]
    bd = [f"BD_{alt}_2018"]
    om = [f"OM_{alt}_2018"]
    thetaFC = [f"θFC_{alt}"]
    thetaPWP = [f"θPWP_{alt}"]
    ksat = [f"Ksat_{alt}"]
    porosity = [f"Porosity_{alt}_2018"]

    feature_combo = [
        ntr,  # 0
        ntr + ndvi,  # 1
        ntr + psd,  # 2
        ntr + ndvi + psd,  # 3
        ntr + ndvi + psd + bd,  # 4
        ntr + ndvi + psd + bd + om,  # 5
        ntr + ndvi + psd + bd + thetaFC,  # 6
        ntr + ndvi + psd + bd + thetaFC + thetaPWP,  # 7
        ntr + ndvi + thetaFC + thetaPWP,  # 8
        ntr + ndvi + psd + bd + om + thetaFC + thetaPWP,  # 9
        ntr + ndvi + psd + bd + om + thetaFC + thetaPWP + ksat,  # 10
        ntr + ndvi + psd + om + porosity,  # 11
    ]

    if check:
        print([f"{depth} cm"] + feature_combo[mode])

    return feature_combo[mode], f"{depth} cm"

# %%
df = pd.read_excel("/content/gdrive/My Drive/Linux Shared Folder/Soil moisture/Data_NEW_data_v2.xlsx")

# %%
df = df.sample(frac=1, random_state=global_seed).reset_index(drop=True)

# %%
def data_split(data, train_split, valid_split):
    n = data.shape[0]
    train = data.iloc[0:int(n * train_split)]
    valid = data.iloc[int(n * train_split):int(n * (train_split + valid_split ))]
    test = data.iloc[int(n * (train_split + valid_split )):n]

    train = h2o.H2OFrame(train)
    test = h2o.H2OFrame(test)
    valid = h2o.H2OFrame(valid)

    return train, test, valid

# %%
train, test, valid = data_split(data=df, train_split=0.5, valid_split=0.2)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
models = []

log = pd.DataFrame(columns=["depth", "mode", "RMSE", "R2", "y_pred", "y_test"])

# %%
count = 0

# %%
for d in [50]:
    for m in range(12):
        count += 1
        print(f"Pass {count}")

        x, y = featureSelect(d, m)
        x = ["2 cm", "10 cm"] + x

        print(x)

        aml = H2OAutoML(max_models=10, seed=global_seed, include_algos = ["DeepLearning"], sort_metric="RMSE", verbosity="info")
        aml.train(x=x, y=y, training_frame=train, validation_frame=valid)

        preds = aml.leader.predict(test)

        y_pred = preds.as_data_frame()
        y_test = test[y].as_data_frame()

        mse = mean_squared_error(y_test, y_pred)
        rmse = np.sqrt(mse)

        r2 = r2_score(y_test, y_pred)

        models.append(aml.leader)
        h2o.save_model(aml.leader, path=f"/content/gdrive/My Drive/Linux Shared Folder/Soil moisture/models/run_5_with_BOTH/data_{d}_{m}/")

        log = log.append(
            {
                "depth": d,
                "mode": m,
                "RMSE": rmse,
                "R2": r2,
                "y_pred": y_pred,
                "y_test": y_test,
            },
            ignore_index=True,
        )

        log.to_excel("/content/gdrive/My Drive/Linux Shared Folder/Soil moisture/models/run_5_with_BOTH/log_h2o_run_5_with_BOTH.xlsx")
# Out:
# Pass 1
# ['2 cm', '10 cm', 'NTR']
# AutoML progress: |
# 01:09:32.903: Project: AutoML_20201103_10932891
# 01:09:32.906: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 01:09:32.906: Setting stopping tolerance adaptively based on the training frame: 0.05
# 01:09:32.906: Build control seed: 42
# 01:09:32.908: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 01:09:32.908: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 01:09:32.909: leaderboard frame: NULL
# 01:09:32.909: blending frame: NULL
# 01:09:32.909: response column: 50 cm
# 01:09:32.909: fold column: null
# 01:09:32.909: weights column: null
# 01:09:32.957: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 01:09:32.975: Disabling Algo: StackedEnsemble as requested by the user.
# 01:09:32.975: Disabling Algo: GBM as requested by the user.
# 01:09:32.975: Disabling Algo: DRF as requested by the user.
# 01:09:32.975: Disabling Algo: XGBoost as requested by the user.
# 01:09:32.976: Disabling Algo: GLM as requested by the user.
# 01:09:32.982: AutoML job created: 2020.11.03 01:09:32.891
# 01:09:32.983: AutoML build started: 2020.11.03 01:09:32.983
# 01:09:33.19: AutoML: starting DeepLearning_1_AutoML_20201103_010932 model training
#
# ██████
# 01:09:44.90: New leader: DeepLearning_1_AutoML_20201103_010932, rmse: 0.11548545609252617
# 01:09:44.92: AutoML: starting DeepLearning_grid__1_AutoML_20201103_010932 hyperparameter search
#
# ███████████
# 01:10:56.123: New leader: DeepLearning_grid__1_AutoML_20201103_010932_model_1, rmse: 0.02070176937623162
#
# ██████
# 01:11:58.134: New leader: DeepLearning_grid__1_AutoML_20201103_010932_model_2, rmse: 0.01878252075852582
#
# ███████
# 01:12:06.140: AutoML: starting DeepLearning_grid__2_AutoML_20201103_010932 hyperparameter search
#
# ███████████████████
# 01:17:26.286: New leader: DeepLearning_grid__2_AutoML_20201103_010932_model_2, rmse: 0.017787687124323277
#
# █
# 01:17:51.294: AutoML: starting DeepLearning_grid__3_AutoML_20201103_010932 hyperparameter search
#
# █████
# 01:23:53.453: New leader: DeepLearning_grid__3_AutoML_20201103_010932_model_2, rmse: 0.016633941759500948
#
# █| 100%
#
# 01:24:28.460: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 01:24:28.462: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 01:24:28.463: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 01:24:28.463: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 01:24:28.463: AutoML build stopped: 2020.11.03 01:24:28.463
# 01:24:28.463: AutoML build done: built 10 models
# 01:24:28.463: AutoML duration: 14 min 55.480 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 2
# ['2 cm', '10 cm', 'NTR', 'NDVI']
# AutoML progress: |
# 01:24:30.692: Project: AutoML_20201103_12430691
# 01:24:30.692: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 01:24:30.692: Setting stopping tolerance adaptively based on the training frame: 0.05
# 01:24:30.692: Build control seed: 42
# 01:24:30.693: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 01:24:30.693: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 01:24:30.693: leaderboard frame: NULL
# 01:24:30.693: blending frame: NULL
# 01:24:30.693: response column: 50 cm
# 01:24:30.693: fold column: null
# 01:24:30.693: weights column: null
# 01:24:30.693: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 01:24:30.694: Disabling Algo: StackedEnsemble as requested by the user.
# 01:24:30.694: Disabling Algo: GBM as requested by the user.
# 01:24:30.694: Disabling Algo: DRF as requested by the user.
# 01:24:30.694: Disabling Algo: XGBoost as requested by the user.
# 01:24:30.694: Disabling Algo: GLM as requested by the user.
# 01:24:30.695: AutoML job created: 2020.11.03 01:24:30.691
# 01:24:30.701: AutoML build started: 2020.11.03 01:24:30.701
# 01:24:30.701: AutoML: starting DeepLearning_1_AutoML_20201103_012430 model training
#
#
# 01:24:31.707: New leader: DeepLearning_1_AutoML_20201103_012430, rmse: 0.10805030642803905
# 01:24:31.708: AutoML: starting DeepLearning_grid__1_AutoML_20201103_012430 hyperparameter search
#
# ███████████████████████████████
# 01:25:42.725: New leader: DeepLearning_grid__1_AutoML_20201103_012430_model_1, rmse: 0.01877947821429453
#
# ███
# 01:26:44.733: New leader: DeepLearning_grid__1_AutoML_20201103_012430_model_2, rmse: 0.018225802505042993
#
# ████
# 01:26:53.736: AutoML: starting DeepLearning_grid__2_AutoML_20201103_012430 hyperparameter search
#
# ██████████████
# 01:32:10.842: AutoML: starting DeepLearning_grid__3_AutoML_20201103_012430 hyperparameter search
#
# ██
# 01:34:27.905: New leader: DeepLearning_grid__3_AutoML_20201103_012430_model_1, rmse: 0.017501143749551737
#
# ██| 100%
#
# 01:38:13.987: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 01:38:13.988: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 01:38:13.988: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 01:38:13.988: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 01:38:13.989: AutoML build stopped: 2020.11.03 01:38:13.989
# 01:38:13.989: AutoML build done: built 10 models
# 01:38:13.989: AutoML duration: 13 min 43.288 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 3
# ['2 cm', '10 cm', 'NTR', 'Clay_L3', 'Sand_L3', 'Silt_L3']
# AutoML progress: |
# 01:38:15.684: Project: AutoML_20201103_13815684
# 01:38:15.685: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 01:38:15.685: Setting stopping tolerance adaptively based on the training frame: 0.05
# 01:38:15.685: Build control seed: 42
# 01:38:15.685: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 01:38:15.685: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 01:38:15.685: leaderboard frame: NULL
# 01:38:15.685: blending frame: NULL
# 01:38:15.685: response column: 50 cm
# 01:38:15.685: fold column: null
# 01:38:15.685: weights column: null
# 01:38:15.686: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 01:38:15.686: Disabling Algo: StackedEnsemble as requested by the user.
# 01:38:15.686: Disabling Algo: GBM as requested by the user.
# 01:38:15.686: Disabling Algo: DRF as requested by the user.
# 01:38:15.686: Disabling Algo: XGBoost as requested by the user.
# 01:38:15.686: Disabling Algo: GLM as requested by the user.
# 01:38:15.687: AutoML job created: 2020.11.03 01:38:15.684
# 01:38:15.687: AutoML build started: 2020.11.03 01:38:15.687
# 01:38:15.687: AutoML: starting DeepLearning_1_AutoML_20201103_013815 model training
#
#
# 01:38:16.689: New leader: DeepLearning_1_AutoML_20201103_013815, rmse: 0.12842607160565578
# 01:38:16.690: AutoML: starting DeepLearning_grid__1_AutoML_20201103_013815 hyperparameter search
#
# █████████████████████████████████████
# 01:39:39.706: New leader: DeepLearning_grid__1_AutoML_20201103_013815_model_1, rmse: 0.014238516741172852
#
# ███
# 01:40:48.722: New leader: DeepLearning_grid__1_AutoML_20201103_013815_model_2, rmse: 0.007021761782320844
#
# ██
# 01:40:56.725: AutoML: starting DeepLearning_grid__2_AutoML_20201103_013815 hyperparameter search
#
# ███████
# 01:43:24.750: New leader: DeepLearning_grid__2_AutoML_20201103_013815_model_1, rmse: 0.005026233261755639
#
# ████
# 01:46:40.796: AutoML: starting DeepLearning_grid__3_AutoML_20201103_013815 hyperparameter search
#
# ███| 100%
#
# 01:52:38.909: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 01:52:38.910: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 01:52:38.910: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 01:52:38.910: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 01:52:38.910: AutoML build stopped: 2020.11.03 01:52:38.910
# 01:52:38.910: AutoML build done: built 10 models
# 01:52:38.910: AutoML duration: 14 min 23.223 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 4
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3']
# AutoML progress: |
# 01:52:39.917: Project: AutoML_20201103_15239917
# 01:52:39.917: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 01:52:39.917: Setting stopping tolerance adaptively based on the training frame: 0.05
# 01:52:39.917: Build control seed: 42
# 01:52:39.917: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 01:52:39.917: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 01:52:39.917: leaderboard frame: NULL
# 01:52:39.917: blending frame: NULL
# 01:52:39.917: response column: 50 cm
# 01:52:39.917: fold column: null
# 01:52:39.917: weights column: null
# 01:52:39.918: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 01:52:39.918: Disabling Algo: StackedEnsemble as requested by the user.
# 01:52:39.918: Disabling Algo: GBM as requested by the user.
# 01:52:39.918: Disabling Algo: DRF as requested by the user.
# 01:52:39.918: Disabling Algo: XGBoost as requested by the user.
# 01:52:39.918: Disabling Algo: GLM as requested by the user.
# 01:52:39.918: AutoML job created: 2020.11.03 01:52:39.916
# 01:52:39.919: AutoML build started: 2020.11.03 01:52:39.919
# 01:52:39.919: AutoML: starting DeepLearning_1_AutoML_20201103_015239 model training
#
#
# 01:52:40.921: New leader: DeepLearning_1_AutoML_20201103_015239, rmse: 0.10590742730040104
# 01:52:40.921: AutoML: starting DeepLearning_grid__1_AutoML_20201103_015239 hyperparameter search
#
# ████████████████████████████████████
# 01:54:08.938: New leader: DeepLearning_grid__1_AutoML_20201103_015239_model_1, rmse: 0.01395377433240482
#
# ██████
# 01:55:23.953: New leader: DeepLearning_grid__1_AutoML_20201103_015239_model_2, rmse: 0.008750878202722771
# 01:55:32.955: New leader: DeepLearning_grid__1_AutoML_20201103_015239_model_3, rmse: 0.008378764568016723
# 01:55:32.955: AutoML: starting DeepLearning_grid__2_AutoML_20201103_015239 hyperparameter search
#
# ███████
# 01:58:07.26: New leader: DeepLearning_grid__2_AutoML_20201103_015239_model_1, rmse: 0.008109750233141465
#
# ████
# 02:01:24.68: AutoML: starting DeepLearning_grid__3_AutoML_20201103_015239 hyperparameter search
#
# ███| 100%
#
# 02:07:59.215: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 02:07:59.215: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 02:07:59.216: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 02:07:59.216: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 02:07:59.216: AutoML build stopped: 2020.11.03 02:07:59.216
# 02:07:59.216: AutoML build done: built 10 models
# 02:07:59.217: AutoML duration: 15 min 19.297 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 5
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018']
# AutoML progress: |
# 02:08:00.96: Project: AutoML_20201103_20800095
# 02:08:00.96: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 02:08:00.97: Setting stopping tolerance adaptively based on the training frame: 0.05
# 02:08:00.97: Build control seed: 42
# 02:08:00.97: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 02:08:00.97: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 02:08:00.97: leaderboard frame: NULL
# 02:08:00.97: blending frame: NULL
# 02:08:00.97: response column: 50 cm
# 02:08:00.97: fold column: null
# 02:08:00.97: weights column: null
# 02:08:00.97: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 02:08:00.99: Disabling Algo: StackedEnsemble as requested by the user.
# 02:08:00.99: Disabling Algo: GBM as requested by the user.
# 02:08:00.99: Disabling Algo: DRF as requested by the user.
# 02:08:00.99: Disabling Algo: XGBoost as requested by the user.
# 02:08:00.99: Disabling Algo: GLM as requested by the user.
# 02:08:00.100: AutoML job created: 2020.11.03 02:08:00.95
# 02:08:00.101: AutoML build started: 2020.11.03 02:08:00.101
# 02:08:00.101: AutoML: starting DeepLearning_1_AutoML_20201103_020800 model training
#
#
# 02:08:01.103: New leader: DeepLearning_1_AutoML_20201103_020800, rmse: 0.10647264083101195
# 02:08:01.103: AutoML: starting DeepLearning_grid__1_AutoML_20201103_020800 hyperparameter search
#
# ████████████████████████████
# 02:09:38.122: New leader: DeepLearning_grid__1_AutoML_20201103_020800_model_1, rmse: 0.011887899095982958
#
# ███████
# 02:10:55.138: New leader: DeepLearning_grid__1_AutoML_20201103_020800_model_2, rmse: 0.009441245834517548
# 02:11:04.140: New leader: DeepLearning_grid__1_AutoML_20201103_020800_model_3, rmse: 0.008171341753305295
# 02:11:04.141: AutoML: starting DeepLearning_grid__2_AutoML_20201103_020800 hyperparameter search
#
# ██████████
# 02:13:30.199: New leader: DeepLearning_grid__2_AutoML_20201103_020800_model_1, rmse: 0.007027971376828187
#
# ██████
# 02:16:17.310: AutoML: starting DeepLearning_grid__3_AutoML_20201103_020800 hyperparameter search
#
# █████| 100%
#
# 02:23:22.562: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 02:23:22.562: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 02:23:22.562: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 02:23:22.562: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 02:23:22.562: AutoML build stopped: 2020.11.03 02:23:22.562
# 02:23:22.562: AutoML build done: built 10 models
# 02:23:22.562: AutoML duration: 15 min 22.461 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 6
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018', 'OM_L3_2018']
# AutoML progress: |
# 02:23:23.964: Project: AutoML_20201103_22323964
# 02:23:23.965: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 02:23:23.965: Setting stopping tolerance adaptively based on the training frame: 0.05
# 02:23:23.965: Build control seed: 42
# 02:23:23.965: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 02:23:23.965: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 02:23:23.965: leaderboard frame: NULL
# 02:23:23.965: blending frame: NULL
# 02:23:23.965: response column: 50 cm
# 02:23:23.965: fold column: null
# 02:23:23.965: weights column: null
# 02:23:23.965: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 02:23:23.966: Disabling Algo: StackedEnsemble as requested by the user.
# 02:23:23.966: Disabling Algo: GBM as requested by the user.
# 02:23:23.966: Disabling Algo: DRF as requested by the user.
# 02:23:23.966: Disabling Algo: XGBoost as requested by the user.
# 02:23:23.966: Disabling Algo: GLM as requested by the user.
# 02:23:23.966: AutoML job created: 2020.11.03 02:23:23.964
# 02:23:23.966: AutoML build started: 2020.11.03 02:23:23.966
# 02:23:23.967: AutoML: starting DeepLearning_1_AutoML_20201103_022323 model training
#
#
# 02:23:24.969: New leader: DeepLearning_1_AutoML_20201103_022323, rmse: 0.13999983363993967
# 02:23:24.969: AutoML: starting DeepLearning_grid__1_AutoML_20201103_022323 hyperparameter search
#
# ████████████████████████████████████
# 02:25:03.983: New leader: DeepLearning_grid__1_AutoML_20201103_022323_model_1, rmse: 0.01022763404386426
#
# ███████
# 02:26:27.993: New leader: DeepLearning_grid__1_AutoML_20201103_022323_model_2, rmse: 0.00911753321722029
# 02:26:37.6: New leader: DeepLearning_grid__1_AutoML_20201103_022323_model_3, rmse: 0.008338614057394078
# 02:26:37.6: AutoML: starting DeepLearning_grid__2_AutoML_20201103_022323 hyperparameter search
#
# ██████
# 02:29:35.85: New leader: DeepLearning_grid__2_AutoML_20201103_022323_model_1, rmse: 0.00799550342276781
#
# ████
# 02:32:36.182: AutoML: starting DeepLearning_grid__3_AutoML_20201103_022323 hyperparameter search
#
# ███| 100%
#
# 02:38:32.336: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 02:38:32.337: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 02:38:32.337: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 02:38:32.337: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 02:38:32.337: AutoML build stopped: 2020.11.03 02:38:32.337
# 02:38:32.337: AutoML build done: built 10 models
# 02:38:32.337: AutoML duration: 15 min  8.371 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 7
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018', 'θFC_L3']
# AutoML progress: |
# 02:38:34.69: Project: AutoML_20201103_23834069
# 02:38:34.70: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 02:38:34.70: Setting stopping tolerance adaptively based on the training frame: 0.05
# 02:38:34.70: Build control seed: 42
# 02:38:34.70: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 02:38:34.70: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 02:38:34.70: leaderboard frame: NULL
# 02:38:34.70: blending frame: NULL
# 02:38:34.70: response column: 50 cm
# 02:38:34.70: fold column: null
# 02:38:34.70: weights column: null
# 02:38:34.70: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 02:38:34.70: Disabling Algo: StackedEnsemble as requested by the user.
# 02:38:34.70: Disabling Algo: GBM as requested by the user.
# 02:38:34.70: Disabling Algo: DRF as requested by the user.
# 02:38:34.70: Disabling Algo: XGBoost as requested by the user.
# 02:38:34.70: Disabling Algo: GLM as requested by the user.
# 02:38:34.71: AutoML job created: 2020.11.03 02:38:34.69
# 02:38:34.71: AutoML build started: 2020.11.03 02:38:34.71
# 02:38:34.71: AutoML: starting DeepLearning_1_AutoML_20201103_023834 model training
#
#
# 02:38:35.75: New leader: DeepLearning_1_AutoML_20201103_023834, rmse: 0.10224033913526512
# 02:38:35.75: AutoML: starting DeepLearning_grid__1_AutoML_20201103_023834 hyperparameter search
#
# ████████████████████████████
# 02:40:16.105: New leader: DeepLearning_grid__1_AutoML_20201103_023834_model_1, rmse: 0.01477589645231041
#
# █████████
# 02:41:40.117: New leader: DeepLearning_grid__1_AutoML_20201103_023834_model_2, rmse: 0.010114967969003125
# 02:41:49.119: New leader: DeepLearning_grid__1_AutoML_20201103_023834_model_3, rmse: 0.00850336335656009
# 02:41:49.120: AutoML: starting DeepLearning_grid__2_AutoML_20201103_023834 hyperparameter search
#
# ████████
# 02:44:28.221: New leader: DeepLearning_grid__2_AutoML_20201103_023834_model_1, rmse: 0.008473718534404508
#
# ███████
# 02:48:25.363: AutoML: starting DeepLearning_grid__3_AutoML_20201103_023834 hyperparameter search
#
# ████| 100%
#
# 02:54:50.580: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 02:54:50.580: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 02:54:50.581: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 02:54:50.581: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 02:54:50.581: AutoML build stopped: 2020.11.03 02:54:50.581
# 02:54:50.581: AutoML build done: built 10 models
# 02:54:50.581: AutoML duration: 16 min 16.510 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 8
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018', 'θFC_L3', 'θPWP_L3']
# AutoML progress: |
# 02:54:52.286: Project: AutoML_20201103_25452286
# 02:54:52.286: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 02:54:52.286: Setting stopping tolerance adaptively based on the training frame: 0.05
# 02:54:52.286: Build control seed: 42
# 02:54:52.286: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 02:54:52.286: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 02:54:52.286: leaderboard frame: NULL
# 02:54:52.287: blending frame: NULL
# 02:54:52.287: response column: 50 cm
# 02:54:52.287: fold column: null
# 02:54:52.287: weights column: null
# 02:54:52.287: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 02:54:52.287: Disabling Algo: StackedEnsemble as requested by the user.
# 02:54:52.287: Disabling Algo: GBM as requested by the user.
# 02:54:52.287: Disabling Algo: DRF as requested by the user.
# 02:54:52.287: Disabling Algo: XGBoost as requested by the user.
# 02:54:52.287: Disabling Algo: GLM as requested by the user.
# 02:54:52.287: AutoML job created: 2020.11.03 02:54:52.286
# 02:54:52.293: AutoML build started: 2020.11.03 02:54:52.292
# 02:54:52.293: AutoML: starting DeepLearning_1_AutoML_20201103_025452 model training
#
#
# 02:54:53.295: New leader: DeepLearning_1_AutoML_20201103_025452, rmse: 0.12925914473399802
# 02:54:53.296: AutoML: starting DeepLearning_grid__1_AutoML_20201103_025452 hyperparameter search
#
# ██████████████████████████
# 02:56:37.315: New leader: DeepLearning_grid__1_AutoML_20201103_025452_model_1, rmse: 0.014196753575871829
#
# ███████████
# 02:58:05.325: New leader: DeepLearning_grid__1_AutoML_20201103_025452_model_2, rmse: 0.010322140568066409
# 02:58:14.327: New leader: DeepLearning_grid__1_AutoML_20201103_025452_model_3, rmse: 0.008989769269449032
# 02:58:14.328: AutoML: starting DeepLearning_grid__2_AutoML_20201103_025452 hyperparameter search
#
# █████████
# 03:01:05.467: New leader: DeepLearning_grid__2_AutoML_20201103_025452_model_1, rmse: 0.00887495362842864
#
# ██████
# 03:04:16.593: AutoML: starting DeepLearning_grid__3_AutoML_20201103_025452 hyperparameter search
#
# ████
# 03:09:59.734: New leader: DeepLearning_grid__3_AutoML_20201103_025452_model_2, rmse: 0.008726929572958014
#
# | 100%
#
# 03:10:35.753: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 03:10:35.754: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 03:10:35.754: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 03:10:35.755: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 03:10:35.755: AutoML build stopped: 2020.11.03 03:10:35.755
# 03:10:35.755: AutoML build done: built 10 models
# 03:10:35.755: AutoML duration: 15 min 43.463 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 9
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'θFC_L3', 'θPWP_L3']
# AutoML progress: |
# 03:10:37.392: Project: AutoML_20201103_31037392
# 03:10:37.392: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 03:10:37.392: Setting stopping tolerance adaptively based on the training frame: 0.05
# 03:10:37.392: Build control seed: 42
# 03:10:37.393: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 03:10:37.393: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 03:10:37.393: leaderboard frame: NULL
# 03:10:37.393: blending frame: NULL
# 03:10:37.393: response column: 50 cm
# 03:10:37.393: fold column: null
# 03:10:37.393: weights column: null
# 03:10:37.393: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 03:10:37.394: Disabling Algo: StackedEnsemble as requested by the user.
# 03:10:37.394: Disabling Algo: GBM as requested by the user.
# 03:10:37.394: Disabling Algo: DRF as requested by the user.
# 03:10:37.394: Disabling Algo: XGBoost as requested by the user.
# 03:10:37.394: Disabling Algo: GLM as requested by the user.
# 03:10:37.394: AutoML job created: 2020.11.03 03:10:37.392
# 03:10:37.395: AutoML build started: 2020.11.03 03:10:37.394
# 03:10:37.395: AutoML: starting DeepLearning_1_AutoML_20201103_031037 model training
#
#
# 03:10:38.396: New leader: DeepLearning_1_AutoML_20201103_031037, rmse: 0.128036656740032
# 03:10:38.397: AutoML: starting DeepLearning_grid__1_AutoML_20201103_031037 hyperparameter search
#
# ██████████████████████████
# 03:12:00.420: New leader: DeepLearning_grid__1_AutoML_20201103_031037_model_1, rmse: 0.017187500409485666
#
# ████
# 03:13:10.428: New leader: DeepLearning_grid__1_AutoML_20201103_031037_model_2, rmse: 0.01024397584093705
#
# █████
# 03:13:18.431: AutoML: starting DeepLearning_grid__2_AutoML_20201103_031037 hyperparameter search
#
# ████████████████
# 03:18:57.626: AutoML: starting DeepLearning_grid__3_AutoML_20201103_031037 hyperparameter search
#
# █████| 100%
#
# 03:26:14.793: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 03:26:14.793: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 03:26:14.793: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 03:26:14.794: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 03:26:14.794: AutoML build stopped: 2020.11.03 03:26:14.794
# 03:26:14.794: AutoML build done: built 10 models
# 03:26:14.794: AutoML duration: 15 min 37.400 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 10
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018', 'OM_L3_2018', 'θFC_L3', 'θPWP_L3']
# AutoML progress: |
# 03:26:16.184: Project: AutoML_20201103_32616184
# 03:26:16.184: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 03:26:16.184: Setting stopping tolerance adaptively based on the training frame: 0.05
# 03:26:16.184: Build control seed: 42
# 03:26:16.184: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 03:26:16.184: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 03:26:16.184: leaderboard frame: NULL
# 03:26:16.185: blending frame: NULL
# 03:26:16.186: response column: 50 cm
# 03:26:16.186: fold column: null
# 03:26:16.186: weights column: null
# 03:26:16.186: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 03:26:16.186: Disabling Algo: StackedEnsemble as requested by the user.
# 03:26:16.186: Disabling Algo: GBM as requested by the user.
# 03:26:16.186: Disabling Algo: DRF as requested by the user.
# 03:26:16.186: Disabling Algo: XGBoost as requested by the user.
# 03:26:16.186: Disabling Algo: GLM as requested by the user.
# 03:26:16.187: AutoML job created: 2020.11.03 03:26:16.184
# 03:26:16.188: AutoML build started: 2020.11.03 03:26:16.188
# 03:26:16.188: AutoML: starting DeepLearning_1_AutoML_20201103_032616 model training
#
#
# 03:26:17.190: New leader: DeepLearning_1_AutoML_20201103_032616, rmse: 0.09678859251613088
# 03:26:17.190: AutoML: starting DeepLearning_grid__1_AutoML_20201103_032616 hyperparameter search
#
# ███████████████████████████
# 03:28:00.218: New leader: DeepLearning_grid__1_AutoML_20201103_032616_model_1, rmse: 0.014910817134556427
#
# ████████████
# 03:29:33.232: New leader: DeepLearning_grid__1_AutoML_20201103_032616_model_2, rmse: 0.00884762935977984
# 03:29:43.234: AutoML: starting DeepLearning_grid__2_AutoML_20201103_032616 hyperparameter search
#
# ████████████
# 03:35:19.393: New leader: DeepLearning_grid__2_AutoML_20201103_032616_model_2, rmse: 0.008372331974510108
#
# █
# 03:35:44.397: AutoML: starting DeepLearning_grid__3_AutoML_20201103_032616 hyperparameter search
#
# ████| 100%
#
# 03:42:45.644: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 03:42:45.644: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 03:42:45.644: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 03:42:45.644: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 03:42:45.644: AutoML build stopped: 2020.11.03 03:42:45.644
# 03:42:45.644: AutoML build done: built 10 models
# 03:42:45.644: AutoML duration: 16 min 29.456 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 11
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'BD_L3_2018', 'OM_L3_2018', 'θFC_L3', 'θPWP_L3', 'Ksat_L3']
# AutoML progress: |
# 03:42:47.824: Project: AutoML_20201103_34247823
# 03:42:47.824: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 03:42:47.824: Setting stopping tolerance adaptively based on the training frame: 0.05
# 03:42:47.824: Build control seed: 42
# 03:42:47.824: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 03:42:47.824: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 03:42:47.824: leaderboard frame: NULL
# 03:42:47.824: blending frame: NULL
# 03:42:47.824: response column: 50 cm
# 03:42:47.824: fold column: null
# 03:42:47.824: weights column: null
# 03:42:47.825: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 03:42:47.825: Disabling Algo: StackedEnsemble as requested by the user.
# 03:42:47.825: Disabling Algo: GBM as requested by the user.
# 03:42:47.825: Disabling Algo: DRF as requested by the user.
# 03:42:47.825: Disabling Algo: XGBoost as requested by the user.
# 03:42:47.825: Disabling Algo: GLM as requested by the user.
# 03:42:47.825: AutoML job created: 2020.11.03 03:42:47.823
# 03:42:47.826: AutoML build started: 2020.11.03 03:42:47.826
# 03:42:47.826: AutoML: starting DeepLearning_1_AutoML_20201103_034247 model training
#
#
# 03:42:48.848: New leader: DeepLearning_1_AutoML_20201103_034247, rmse: 0.10301714351325247
# 03:42:48.848: AutoML: starting DeepLearning_grid__1_AutoML_20201103_034247 hyperparameter search
#
# ████████████████████████████████████
# 03:44:28.861: New leader: DeepLearning_grid__1_AutoML_20201103_034247_model_1, rmse: 0.0152624279491096
#
# ████████
# 03:46:06.881: New leader: DeepLearning_grid__1_AutoML_20201103_034247_model_2, rmse: 0.01115236005006009
# 03:46:16.883: New leader: DeepLearning_grid__1_AutoML_20201103_034247_model_3, rmse: 0.00962241604223228
# 03:46:16.884: AutoML: starting DeepLearning_grid__2_AutoML_20201103_034247 hyperparameter search
#
# █████
# 03:49:03.980: New leader: DeepLearning_grid__2_AutoML_20201103_034247_model_1, rmse: 0.006595589450180916
#
# ████
# 03:51:49.77: AutoML: starting DeepLearning_grid__3_AutoML_20201103_034247 hyperparameter search
#
# ███| 100%
#
# 03:59:08.261: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 03:59:08.261: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 03:59:08.262: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 03:59:08.262: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 03:59:08.262: AutoML build stopped: 2020.11.03 03:59:08.262
# 03:59:08.262: AutoML build done: built 10 models
# 03:59:08.262: AutoML duration: 16 min 20.436 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%
# Pass 12
# ['2 cm', '10 cm', 'NTR', 'NDVI', 'Clay_L3', 'Sand_L3', 'Silt_L3', 'OM_L3_2018', 'Porosity_L3_2018']
# AutoML progress: |
# 03:59:09.780: Project: AutoML_20201103_35909780
# 03:59:09.781: User specified a validation frame with cross-validation still enabled. Please note that the models will still be validated using cross-validation only, the validation frame will be used to provide purely informative validation metrics on the trained models.
# 03:59:09.781: Setting stopping tolerance adaptively based on the training frame: 0.05
# 03:59:09.781: Build control seed: 42
# 03:59:09.781: training frame: Frame key: automl_training_Key_Frame__upload_81af2b247db8be27e5b98a5c14084b45.hex    cols: 26    rows: 15  chunks: 1    size: 5041  checksum: -3098367329305361756
# 03:59:09.781: validation frame: Frame key: Key_Frame__upload_badff9fede1f66157cdbda1c2b0431f.hex    cols: 26    rows: 6  chunks: 1    size: 3502  checksum: 977281445782166532
# 03:59:09.781: leaderboard frame: NULL
# 03:59:09.781: blending frame: NULL
# 03:59:09.781: response column: 50 cm
# 03:59:09.781: fold column: null
# 03:59:09.781: weights column: null
# 03:59:09.781: Loading execution steps: [{XGBoost : defaults}, {GLM : defaults}, {DRF : [def_1]}, {GBM : defaults}, {DeepLearning : defaults}, {DRF : [XRT]}, {XGBoost : grids}, {GBM : grids}, {DeepLearning : grids}, {GBM : [lr_annealing]}, {XGBoost : [lr_search]}, {StackedEnsemble : defaults}]
# 03:59:09.782: Disabling Algo: StackedEnsemble as requested by the user.
# 03:59:09.782: Disabling Algo: GBM as requested by the user.
# 03:59:09.782: Disabling Algo: DRF as requested by the user.
# 03:59:09.782: Disabling Algo: XGBoost as requested by the user.
# 03:59:09.782: Disabling Algo: GLM as requested by the user.
# 03:59:09.782: AutoML job created: 2020.11.03 03:59:09.780
# 03:59:09.783: AutoML build started: 2020.11.03 03:59:09.783
# 03:59:09.784: AutoML: starting DeepLearning_1_AutoML_20201103_035909 model training
#
#
# 03:59:10.785: New leader: DeepLearning_1_AutoML_20201103_035909, rmse: 0.1107500396908323
# 03:59:10.785: AutoML: starting DeepLearning_grid__1_AutoML_20201103_035909 hyperparameter search
#
# ██████████████████████████████
# 04:00:48.798: New leader: DeepLearning_grid__1_AutoML_20201103_035909_model_1, rmse: 0.015368319032436423
#
# ████████
# 04:02:14.838: New leader: DeepLearning_grid__1_AutoML_20201103_035909_model_2, rmse: 0.008663547619359979
# 04:02:23.840: New leader: DeepLearning_grid__1_AutoML_20201103_035909_model_3, rmse: 0.008394385104032084
# 04:02:23.841: AutoML: starting DeepLearning_grid__2_AutoML_20201103_035909 hyperparameter search
#
# █████████
# 04:04:55.887: New leader: DeepLearning_grid__2_AutoML_20201103_035909_model_1, rmse: 0.008157026996929823
#
# █████
# 04:08:20.943: AutoML: starting DeepLearning_grid__3_AutoML_20201103_035909 hyperparameter search
#
# ████| 100%
#
# 04:14:44.70: Skipping StackedEnsemble 'best' due to the exclude_algos option.
# 04:14:44.71: Skipping StackedEnsemble 'all' due to the exclude_algos option.
# 04:14:44.71: Skipping StackedEnsemble 'monotonic' due to the exclude_algos option.
# 04:14:44.71: Actual modeling steps: [{DeepLearning : [def_1 (10), grid_1 (20), grid_2 (20), grid_3 (20)]}]
# 04:14:44.71: AutoML build stopped: 2020.11.03 04:14:44.71
# 04:14:44.71: AutoML build done: built 10 models
# 04:14:44.71: AutoML duration: 15 min 34.288 sec
#
# deeplearning prediction progress: |███████████████████████████████████████| 100%

# %%
print("\n-----------------------------------------------End of process-----------------------------------------------")
# Out:
# -----------------------------------------------End of process-----------------------------------------------
